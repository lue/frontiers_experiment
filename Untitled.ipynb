# %%
import cv2
import numpy as np
import glob
from astropy.io import fits


from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets


# %matplotlib inline
import matplotlib.pyplot as plt

# %%
files = glob.glob('HLA/*/*.fits')
print(len(files))
# files = files[2:]
# Out:
# 23

# %%
i=1
d1 = fits.open(files[i])
plt.figure(figsize=(8,8))
plt.subplot(211)
plt.imshow((d1[1].data[2000+500:3000+500,1700-50:2700-50]), origin='lower', vmax = 1.)

i=2
d1 = fits.open(files[i])
plt.subplot(212)
plt.imshow((d1[1].data[2000:3000,1700:2700]), origin='lower', vmax = 1.)

# im1 = d1[1].data[2000:2700,2000:3000].copy()
    
#     plt.im

# %%
d1[1].data[2100:2200, 2000:2100]
# Out:
# array([[0.09382126, 0.08669753, 0.09356849, ..., 0.09261761, 0.0914792 ,
#         0.09138571],
#        [0.09078889, 0.09415723, 0.09401053, ..., 0.10652754, 0.10066385,
#         0.09039637],
#        [0.09184348, 0.0940016 , 0.09096181, ..., 0.0977301 , 0.09394566,
#         0.09380904],
#        ...,
#        [0.0895336 , 0.09037012, 0.09005444, ..., 0.10794529, 0.09758716,
#         0.09269924],
#        [0.09016656, 0.09105574, 0.08947746, ..., 0.11347274, 0.10258409,
#         0.09574107],
#        [0.08773796, 0.08723602, 0.09439185, ..., 0.09855439, 0.1032026 ,
#         0.10151005]], dtype=float32)

# %%
def find_shift(im1, im2, show_image = False):
    im1 -= im1.min()
    im1 = np.log10(im1+1e-2)
    im1 -= im1.min()
    im1 = im1*255./im1.max()
    im1 = im1.astype(np.uint8)

    im2 -= im2.min()
    im2 = np.log10(im2+1e-2)
    im2 -= im2.min()
    im2 = im2*255./im2.max()
    im2 = im2.astype(np.uint8)
    
    # Read the images to be aligned
    # im1 =  im1
    # im2 =  cv2.imread("images/image2.jpg");

    # Convert images to grayscale
    im1_gray = im1
    im2_gray = im2

    # Find size of image1
    sz = im1.shape

    # Define the motion model
    warp_mode = cv2.MOTION_TRANSLATION

    # Define 2x3 or 3x3 matrices and initialize the matrix to identity
    if warp_mode == cv2.MOTION_HOMOGRAPHY :
        warp_matrix = np.eye(3, 3, dtype=np.float32)
    else :
        warp_matrix = np.eye(2, 3, dtype=np.float32)

    # Specify the number of iterations.
    number_of_iterations = 5000;

    # Specify the threshold of the increment
    # in the correlation coefficient between two iterations
    termination_eps = 1e-10;

    # Define termination criteria
    criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, number_of_iterations,  termination_eps)

    # Run the ECC algorithm. The results are stored in warp_matrix.
    (cc, warp_matrix) = cv2.findTransformECC (im1_gray,im2_gray,warp_matrix, warp_mode, criteria)

    if warp_mode == cv2.MOTION_HOMOGRAPHY :
        # Use warpPerspective for Homography 
        im2_aligned = cv2.warpPerspective (im2, warp_matrix, (sz[1],sz[0]), flags=cv2.INTER_LINEAR + cv2.WARP_INVERSE_MAP)
    else :
        # Use warpAffine for Translation, Euclidean and Affine
        im2_aligned = cv2.warpAffine(im2, warp_matrix, (sz[1],sz[0]), flags=cv2.INTER_LINEAR + cv2.WARP_INVERSE_MAP);

    # Show final results
    if show_image:
        cv2.imshow("Image 1", im1)
        cv2.imshow("Image 2", im2)
        cv2.imshow("Aligned Image 2", im2_aligned)
        cv2.waitKey(0)
        
    return warp_matrix

# %%
i = -1
d1 = fits.open(files[i])

shifts = []

for i in range(0, len(files)):
    d2 = fits.open(files[i])
    # plt.figure(figsize=(8,8))
    # plt.imshow((d1[1].data[2000:3000,1700:2700] - d2[1].data[2000:3000,1700:2700]), origin='lower')

#     im1 = d1[1].data[2000:2700,2000:3000].copy()
#     im2 = d2[1].data[2000:2700,2000:3000].copy()
    im1 = d1[1].data[1500:2700,1500:3500].copy()
    if i == 0:
        sx = 300
        sy = -300
    elif i ==1:
        sx = 500
        sy = -50
    else:
        sx = 0
        sy = 0
    im2 = d2[1].data[1500+sx:2700+sx,1500+sy:3500+sy].copy()
    temp = find_shift(im1, im2)
    print(temp)
    shifts.append(temp)
# Out:
# [[  1.         0.        38.903614]
#  [  0.         1.       -19.020788]]
# [[  1.         0.        27.240278]
#  [  0.         1.       -17.921719]]
# [[ 1.         0.         5.8048453]
#  [ 0.         1.        -3.108702 ]]
# [[  1.          0.        -11.766285 ]
#  [  0.          1.         -1.0244677]]
# [[ 1.          0.          1.570853  ]
#  [ 0.          1.         -0.16326784]]
# [[ 1.         0.        -5.0511284]
#  [ 0.         1.         8.0385685]]
# [[ 1.        0.       -9.166344]
#  [ 0.        1.        4.270524]]
# [[ 1.         0.        -3.0773206]
#  [ 0.         1.         1.518212 ]]
# [[ 1.        0.       -5.298048]
#  [ 0.        1.       -2.791942]]
# [[ 1.        0.       -7.654094]
#  [ 0.        1.       -9.704731]]
# [[1.        0.        1.3917865]
#  [0.        1.        2.7721808]]
# [[ 1.         0.        -4.180746 ]
#  [ 0.         1.        -0.3613739]]
# [[1.        0.        2.0774903]
#  [0.        1.        1.0809407]]
# [[ 1.        0.       -3.300728]
#  [ 0.        1.        6.356406]]
# [[ 1.         0.        -2.1731534]
#  [ 0.         1.         7.7812505]]
# [[ 1.         0.        -1.4883301]
#  [ 0.         1.         2.358095 ]]
# [[ 1.         0.        -9.451816 ]
#  [ 0.         1.         4.4430633]]
# [[ 1.        0.       -0.405834]
#  [ 0.        1.        6.125026]]
# [[ 1.         0.        -1.3038818]
#  [ 0.         1.        -4.8049116]]
# [[ 1.         0.         1.9701172]
#  [ 0.         1.        -2.129323 ]]
# [[ 1.         0.        -7.2562995]
#  [ 0.         1.         1.9505936]]
# [[ 1.          0.         -0.44427425]
#  [ 0.          1.          9.546628  ]]
# [[ 1.000000e+00  0.000000e+00 -5.408926e-10]
#  [ 0.000000e+00  1.000000e+00  6.710228e-11]]

# %%
shifts
# Out:
# [array([[  1.      ,   0.      ,  38.903614],
#         [  0.      ,   1.      , -19.020788]], dtype=float32),
#  array([[  1.      ,   0.      ,  27.240278],
#         [  0.      ,   1.      , -17.921719]], dtype=float32),
#  array([[ 1.       ,  0.       ,  5.8048453],
#         [ 0.       ,  1.       , -3.108702 ]], dtype=float32),
#  array([[  1.       ,   0.       , -11.766285 ],
#         [  0.       ,   1.       ,  -1.0244677]], dtype=float32),
#  array([[ 1.        ,  0.        ,  1.570853  ],
#         [ 0.        ,  1.        , -0.16326784]], dtype=float32),
#  array([[ 1.       ,  0.       , -5.0511284],
#         [ 0.       ,  1.       ,  8.0385685]], dtype=float32),
#  array([[ 1.      ,  0.      , -9.166344],
#         [ 0.      ,  1.      ,  4.270524]], dtype=float32),
#  array([[ 1.       ,  0.       , -3.0773206],
#         [ 0.       ,  1.       ,  1.518212 ]], dtype=float32),
#  array([[ 1.      ,  0.      , -5.298048],
#         [ 0.      ,  1.      , -2.791942]], dtype=float32),
#  array([[ 1.      ,  0.      , -7.654094],
#         [ 0.      ,  1.      , -9.704731]], dtype=float32),
#  array([[1.       , 0.       , 1.3917865],
#         [0.       , 1.       , 2.7721808]], dtype=float32),
#  array([[ 1.       ,  0.       , -4.180746 ],
#         [ 0.       ,  1.       , -0.3613739]], dtype=float32),
#  array([[1.       , 0.       , 2.0774903],
#         [0.       , 1.       , 1.0809407]], dtype=float32),
#  array([[ 1.      ,  0.      , -3.300728],
#         [ 0.      ,  1.      ,  6.356406]], dtype=float32),
#  array([[ 1.       ,  0.       , -2.1731534],
#         [ 0.       ,  1.       ,  7.7812505]], dtype=float32),
#  array([[ 1.       ,  0.       , -1.4883301],
#         [ 0.       ,  1.       ,  2.358095 ]], dtype=float32),
#  array([[ 1.       ,  0.       , -9.451816 ],
#         [ 0.       ,  1.       ,  4.4430633]], dtype=float32),
#  array([[ 1.      ,  0.      , -0.405834],
#         [ 0.      ,  1.      ,  6.125026]], dtype=float32),
#  array([[ 1.       ,  0.       , -1.3038818],
#         [ 0.       ,  1.       , -4.8049116]], dtype=float32),
#  array([[ 1.       ,  0.       ,  1.9701172],
#         [ 0.       ,  1.       , -2.129323 ]], dtype=float32),
#  array([[ 1.       ,  0.       , -7.2562995],
#         [ 0.       ,  1.       ,  1.9505936]], dtype=float32),
#  array([[ 1.        ,  0.        , -0.44427425],
#         [ 0.        ,  1.        ,  9.546628  ]], dtype=float32),
#  array([[ 1.000000e+00,  0.000000e+00, -5.408926e-10],
#         [ 0.000000e+00,  1.000000e+00,  6.710228e-11]], dtype=float32)]

# %%
for i in range(0, len(files)):
    d2 = fits.open(files[i])
    print(d2[0].header['EXPTIME'])
# Out:
# 3840.0
# 9600.0
# 5146.0
# 5146.0
# 5146.0
# 5146.0
# 5146.0
# 5146.0
# 5146.0
# 5146.0
# 5146.0
# 4981.0
# 4981.0
# 4981.0
# 5080.0
# 5080.0
# 5080.0
# 5080.0
# 5080.0
# 5080.0
# 5080.0
# 5080.0
# 5080.0

# %%
def oversample(x, n, sx, sy):
    s = x.shape
    res = np.zeros([s[0]*n, s[1]*n])
    for i in range(s[0]):
        for j in range(s[1]):
            res[i*n-sx:(i+1)*n-sx, j*n-sy:(j+1)*n-sy] = x[i,j]
    return res

# %%
d2[0].header['DATE-OBS']

dat_all = []
date_all = []
for i in range(len(files)):
    d1 = fits.open(files[i])
    sx = -int(np.floor(shifts[i][1,2]))
    ssx = -(shifts[i][1,2] + sx)
    sy = -int(np.floor(shifts[i][0,2]))
    ssy = -(shifts[i][0,2] + sy)
    if i == 0:
        sx -= 300
        sy -= -300
    elif i ==1:
        sx -= 500
        sy -= -50
#     dat = d1[1].data[2100-sx:2250-sx,2250-sy:2750-sy]
    dat = d1[1].data[2100-sx:2250-sx,2250-sy:2750-sy]
    dat /= np.median(dat)
    od = 10
    dat = oversample(dat, od, -int(ssx*od), -int(ssy*od))
#     dat /= d1[0].header['EXPTIME']
    print(d1[0].header['DATE-OBS'])
    dat_all.append(dat)
    date_all.append(d1[0].header['DATE-OBS'])

date_all = np.array(date_all)
dat_all = np.array(dat_all)
# Out:
# 2009-07-16
# 2010-12-20
# 2016-01-18
# 2015-12-22
# 2015-12-28
# 2015-12-24
# 2016-01-20
# 2016-01-10
# 2016-01-11
# 2016-01-28
# 2016-01-03
# 2016-01-13
# 2016-01-17
# 2016-01-23
# 2015-12-19
# 2015-12-20
# 2015-12-21
# 2015-12-24
# 2015-12-26
# 2015-12-26
# 2015-12-27
# 2015-12-29
# 2016-01-02

# %%
i = np.argsort(date_all)
date_all = date_all[i]
dat_all = dat_all[i]

# %%
    
def f(i):
    plt.figure(2, figsize=(14,6))
    print(date_all[i])
    plt.imshow(dat_all[i], vmin=0., vmax=3., origin='lower')
    plt.show()

interactive_plot = interactive(f, i=(0, len(files)-1, 1))
output = interactive_plot.children[-1]
# output.layout.width = '1000px'
interactive_plot

# i = 0
# d1 = fits.open(files[i])
# plt.imshow(d1[1].data[2100+sx:2250+sx,2200+sy:2800+sy], vmax=.2)
# Out:
# interactive(children=(IntSlider(value=11, description='i', max=22), Output()), _dom_classes=('widget-interact'…

# %%
from matplotlib.colors import LogNorm

q = plt.hist2d(dat_all.std(0).flatten(), dat_all.mean(0).flatten(), 100, norm=LogNorm())

# %%
filt = (dat_all.std(0) > .5) & (dat_all.mean(0) < 2.)

plt.figure(figsize=(14,8))
plt.imshow(np.log10(np.median(dat_all,0))/filt, vmin=-.1, vmax=1., origin='lower')
# Out:
# C:\Users\akaur\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# C:\Users\akaur\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
plt.figure(figsize=(14,8))
plt.imshow((dat_all.std(0) / dat_all.mean(0)**0.5), vmin=0., vmax=.5, origin='lower')

# %%
plt.figure(figsize=(14,8))
plt.imshow(np.log10(np.median(dat_all,0)), vmin=-.1, vmax=1., origin='lower')
# Out:
# C:\Users\akaur\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10

# %%
plt.figure(figsize=(14,8))
plt.imshow((dat_all.mean(0)/dat_all[3]), origin='lower')
# Out:
# C:\Users\akaur\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %%
warp_matrix

# %%
ls HST
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is D2FD-DE6B
#
#  Directory of C:\work\frontiers_experiment\HST
#
# 07/09/2018  02:53 PM    <DIR>          .
# 07/09/2018  02:53 PM    <DIR>          ..
# 07/09/2018  02:53 PM    <DIR>          jcsza3ilq
# 07/09/2018  02:53 PM    <DIR>          jcsza3irq
# 07/09/2018  02:53 PM    <DIR>          jcsza3iyq
# 07/09/2018  02:53 PM    <DIR>          jcsza3j5q
#                0 File(s)              0 bytes
#                6 Dir(s)  52,421,447,680 bytes free

# %%
files2 = glob.glob("HST\j*\*flt.fits")

# %%
i=1
d1 = fits.open(files2[i])
plt.figure(figsize=(8,8))
# for i in range(1,16):
#     plt.subplot(4,4,i+1)
#     plt.imshow(np.log10(d1[i].data), origin='lower',vmin=-1, vmax=1)

s = [[95, 0],[93, 5],[0, 0],[0 ,10]]


    
def f(i):
    plt.figure(2, figsize=(14,6))
    d1 = fits.open(files2[i])
    plt.imshow(np.log10(d1[4].data[s[i][0]:-1800+s[i][0],s[i][1]+1400:s[i][1]+1600]).T, origin='lower',vmin=1.7, vmax=2.5)
    plt.show()

interactive_plot = interactive(f, i=(0, 3, 1))
output = interactive_plot.children[-1]
# output.layout.width = '1000px'
interactive_plot

# i = 0
# Out:
# interactive(children=(IntSlider(value=1, description='i', max=3), Output()), _dom_classes=('widget-interact',)…

# %%
i = 0
d1 = fits.open(files2[i])
im1 = (d1[4].data[:-1500,1000:2000]).T
shifts = []

for i in range(2, len(files2)):
    d2 = fits.open(files2[i])
    im2 = (d2[4].data[:-1500,1000:2000]).T
    temp = find_shift(im1, im2)
    print(temp)
#     shifts.append(temp)
# Out:
# [[ 1.          0.         -0.03092727]
#  [ 0.          1.          0.00704613]]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-94-b76b39c50dc2> in <module>()
#       7     d2 = fits.open(files2[i])
#       8     im2 = (d2[4].data[:-1500,1000:2000]).T
# ----> 9     temp = find_shift(im1, im2)
#      10     print(temp)
#      11 #     shifts.append(temp)
#
# <ipython-input-4-cb897bb8ed51> in find_shift(im1, im2, show_image)
#      43
#      44     # Run the ECC algorithm. The results are stored in warp_matrix.
# ---> 45     (cc, warp_matrix) = cv2.findTransformECC (im1_gray,im2_gray,warp_matrix, warp_mode, criteria)
#      46
#      47     if warp_mode == cv2.MOTION_HOMOGRAPHY :
#
# error: C:\ci\opencv_1512688052760\work\modules\video\src\ecc.cpp:540: error: (-7) The algorithm stopped before its convergence. The correlation is going to be minimized. Images may be uncorrelated or non-overlapped in function cv::findTransformECC

# %%
np.isnan(im2).sum()
# Out:
# 0
